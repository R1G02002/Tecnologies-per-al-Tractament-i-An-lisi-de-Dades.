# %%
x=1

# %%
# !git add A.ipynb

# %%
y=2

# %%
# !git commit -m "act1"
# Out:
# [main c982bce] act1
#  1 file changed, 83 insertions(+)
#  create mode 100644 A.ipynb

# %%
# !git status > log.txt

# %%
# !git log --reverse --date=iso --pretty=format:"%ad | %s" > tiempos.txt
